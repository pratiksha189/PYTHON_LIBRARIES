# %%
import pandas as pd
import numpy as np

# %%
people = {'first' : ['Shivansh', 'Rudra', 'Anish', np.nan, 'Avani', np.nan, 'NA'],
            'last' : ['P', 'N', 'Missing', 'NA', 'Missing', None, np.nan],
            'email' : ['shiv@gmail.com', 'rudra@gmail.com', 'anish@gmail.com', 'NA', 'avani@gmail.com', np.nan, np.nan],
             'age' : [42, 13, 43, None, 15, None, 40]}
df = pd.DataFrame(people)
df
# Out:
#       first     last            email   age
# 0  Shivansh        P   shiv@gmail.com  42.0
# 1     Rudra        N  rudra@gmail.com  13.0
# 2     Anish  Missing  anish@gmail.com  43.0
# 3       NaN       NA               NA   NaN
# 4     Avani  Missing  avani@gmail.com  15.0
# 5       NaN     None              NaN   NaN
# 6        NA      NaN              NaN  40.0

# %%
df.dropna(how='any')
# Out:
#       first     last            email   age
# 0  Shivansh        P   shiv@gmail.com  42.0
# 1     Rudra        N  rudra@gmail.com  13.0
# 2     Anish  Missing  anish@gmail.com  43.0
# 4     Avani  Missing  avani@gmail.com  15.0

# %%
df.dropna(how='all')
# Out:
#       first     last            email   age
# 0  Shivansh        P   shiv@gmail.com  42.0
# 1     Rudra        N  rudra@gmail.com  13.0
# 2     Anish  Missing  anish@gmail.com  43.0
# 3       NaN       NA               NA   NaN
# 4     Avani  Missing  avani@gmail.com  15.0
# 6        NA      NaN              NaN  40.0

# %%
df.dropna(subset=['email'])
# Out:
#       first     last            email   age
# 0  Shivansh        P   shiv@gmail.com  42.0
# 1     Rudra        N  rudra@gmail.com  13.0
# 2     Anish  Missing  anish@gmail.com  43.0
# 3       NaN       NA               NA   NaN
# 4     Avani  Missing  avani@gmail.com  15.0

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3   True  False  False   True
# 4  False  False  False  False
# 5   True   True   True   True
# 6  False   True   True  False

# %%
df.fillna({'email': 'NA','age':0})
# Out:
#       first     last            email   age
# 0  Shivansh        P   shiv@gmail.com  42.0
# 1     Rudra        N  rudra@gmail.com  13.0
# 2     Anish  Missing  anish@gmail.com  43.0
# 3       NaN       NA               NA   0.0
# 4     Avani  Missing  avani@gmail.com  15.0
# 5       NaN     None               NA   0.0
# 6        NA      NaN               NA  40.0
