# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['ConvertedCompYearly'].min()
# Out:
# np.float64(1.0)

# %%
df['ConvertedCompYearly'].max()
# Out:
# np.float64(74351432.0)

# %%
df['ConvertedCompYearly'].mean()
# Out:
# np.float64(103110.08171765343)

# %%
df['ConvertedCompYearly'].std()
# Out:
# np.float64(681418.8387120209)

# %%
df['ConvertedCompYearly'].agg(['min', 'max', 'mean', 'median'])
# Out:
# min       1.000000e+00
# max       7.435143e+07
# mean      1.031101e+05
# median    7.496300e+04
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].value_counts() #frequency
# Out:
# ConvertedCompYearly
# 64254.0     784
# 53545.0     615
# 150000.0    585
# 200000.0    558
# 74963.0     557
#            ...
# 7336.0        1
# 34660.0       1
# 1606.0        1
# 319711.0      1
# 16917.0       1
# Name: count, Length: 8784, dtype: int64

# %%
df['ConvertedCompYearly'].count() #count of non NA values
# Out:
# np.int64(48019)

# %%
df['ConvertedCompYearly'].nunique() #count of unique values
# Out:
# 8784

# %%
df['ConvertedCompYearly'].unique() #unique values
# Out:
# array([    nan, 285000., 250000., ...,   1606., 319711.,  16917.],
#       shape=(8785,))

# %%
c_groups = df.groupby(df['Country'])
type(c_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
india = c_groups.get_group('India').loc[:, ['Age', 'Country', 'YearsCode', 'LanguageHaveWorkedWith', 'Employment']]
india
# Out:
#                    Age Country YearsCode  \
# 9      25-34 years old   India         6
# 66     25-34 years old   India        10
# 78     18-24 years old   India         5
# 82     25-34 years old   India        10
# 85     25-34 years old   India         7
# ...                ...     ...       ...
# 89119  18-24 years old   India         3
# 89121  18-24 years old   India         4
# 89164  18-24 years old   India         6
# 89165  25-34 years old   India         6
# 89167  18-24 years old   India         6
#
#                                LanguageHaveWorkedWith  \
# 9      HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 66                                     Java;Scala;SQL
# 78                              JavaScript;TypeScript
# 82                                                C++
# 85                 Assembly;C;C++;Java;JavaScript;SQL
# ...                                               ...
# 89119                 Dart;HTML/CSS;JavaScript;Python
# ...

# %%
c_groups['ConvertedCompYearly'].value_counts()
# Out:
# Country      ConvertedCompYearly
# Afghanistan  33.0                   1
#              41.0                   1
#              48.0                   1
#              648.0                  1
#              794.0                  1
#                                    ..
# Zimbabwe     7800.0                 1
#              10000.0                1
#              30000.0                1
#              60000.0                1
#              114000.0               1
# Name: count, Length: 12630, dtype: int64

# %%
c_groups['ConvertedCompYearly'].agg(['min', 'max', 'mean', 'median'])
# Out:
#                                           min        max           mean  \
# Country
# Afghanistan                              33.0  9203683.0  843636.090909
# Albania                                  14.0   139700.0   29219.450000
# Algeria                                 512.0    37776.0   10069.190476
# Andorra                               23560.0   289142.0  120368.800000
# Angola                                  662.0     7942.0    4302.000000
# ...                                       ...        ...            ...
# Venezuela, Bolivarian Republic of...      5.0   180000.0   23068.851852
# Viet Nam                                  1.0   125000.0   20995.956140
# Yemen                                  1500.0    59917.0   15089.333333
# Zambia                                  605.0    41122.0   13897.800000
# Zimbabwe                               3000.0   114000.0   26740.000000
#
#                                        median
# Country
# ...
